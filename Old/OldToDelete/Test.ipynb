# %%
from Interpolation import *

# %%
supported_launchers = {"Ariane_64": ["Korou", 5], "Ariane_62": ["Korou", 5], "Soyuz": ["Baikonur", 45],
                           "Soyuz_2.1a_Fregat": ["Baikonur", 45], "Soyuz_2.1b_Fregat": ["Baikonur", 45]}

# %%
launcher="Soyuz_2.1a_Fregat"

# %%
print(supported_launchers.get(launcher))
# Out:
# ['Baikonur', 45]

# %%
launcher="Soyuz_2.1b_Fregat"
launch_site="Baikonur"
# launcher="Ariane_64"
# launch_site="Korou"

inclination= 87.4
apogee= 450
perigee =apogee
orbit_type="LEO"

# %%
launcher_data, _ = get_launcher_data(launcher, launch_site, orbit_type)

# %%
# interpolate_launcher_data(launcher_data, apogee, perigee, interpolation_method="linear", verbose=True)

# %%
get_launcher_performance(launcher, launch_site, inclination, apogee, perigee, orbit_type ,method="linear",
                             verbose=True)
# Out:
# Close the window to continue.
# Interpolating...
# <Quantity 4685.72193878 kg>

# %%
(5550/4074 -1)*100
# Out:
# 36.229749631811494

# %%
4580/5469-1
# Out:
# -0.16255256902541593

# %%
8.6/7.4
# Out:
# 1.162162162162162

# %%
4074*1.162
# Out:
# 4733.987999999999

# %%
fairing_diameter= None
fairing_cylinder_height= None
fairing_total_heigth = None

# %%
fairing_diameter is None and fairing_cylinder_height is None and fairing_total_heigth is None
# Out:
# True
